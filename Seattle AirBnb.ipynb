# %% [markdown]
# # Business Understand

# %% [markdown]
# ### Background
#    Seattle tourism is booming and the housing price of Seattle is attractive. Investing now will likely guarantee a return in value. Airbnb investing be a viable option for real estate investors.
# ### Business Objectives:
#    Which neigborhood and what type of properties will more likely guarantee a return in value in Airbnb investment?
# ### Data Mining Goal:
# #### To make better investing decision, a few key factors should be considered and analyzed first:
#    * market saturation across neighborhoods<br/>
#    * visitors’ rating on location <br/>
#    * occupancy rates and monthly revenues across neighborhoods<br/>
#    * occupancy rates and monthly revenues by property types<br/>
#
# ####  Data mining success criteria
#    * Define features of listings/calendars that have strong relationships with price and revenue
# ### Project Plan
# #### Gather
# * Data source: Airbnb data for Seattle
# #### Assess
# * Describe data<br/>
# * Explore data for useful features
# #### Clean
# * Select required subset of data<br/>
# * Preprocess categorical data<br/>
# * Preprocess missing data
# #### Analyze
# * Analyze data for answering relevant questions
# #### Visualze
# * Visualize findings
# #### Results
# * Formulate the answers for the business data mining process

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Collect initial data

# %%
#Import libaries and read the listing table
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df = pd.read_csv('C:/Users/Nancy Zhao/Desktop/Nano degrees/Data science/CRISP-DM/data science blog post/listings.csv')
# remove columns with missing values more than 40%
columns = df.columns
columns = columns[(len(df) - df.count()) / len(df) < 0.4]
df = df[columns]

#read the calendar table
df1 = pd.read_csv('C:/Users/Nancy Zhao/Desktop/Nano degrees/Data science/CRISP-DM/data science blog post/calendar.csv')

#merge the listing table and the calendar table by id
df2 = pd.merge(df, df1, left_on = 'id', right_on = 'listing_id')

# %% [markdown]
# ## Describe and explore data

# %%
# Describe and explore df
df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        'transit', 'thumbnail_url', 'medium_url', 'picture_url',
#        'xl_picture_url', 'host_id', 'host_url', 'host_name', 'host_since',
#        'host_location', 'host_about', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood',
#        'host_listings_count', 'host_total_listings_count',
#        'host_verifications', 'host_has_profile_pic', 'host_identity_verified',
#        'street', 'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'jurisdiction_names', 'instant_bookable', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month'],
#       dtype='object')

# %%
df = df[['id', 'host_response_rate', 'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bedrooms', 'beds','price', 'review_scores_rating', 'review_scores_location','cancellation_policy']]
df.head()
# Out:
#         id host_response_rate neighbourhood_cleansed property_type  \
# 0   241032                96%        West Queen Anne     Apartment
# 1   953595                98%        West Queen Anne     Apartment
# 2  3308979                67%        West Queen Anne         House
# 3  7421966                NaN        West Queen Anne     Apartment
# 4   278830               100%        West Queen Anne         House
#
#          room_type  accommodates  bathrooms  bedrooms  beds    price  \
# 0  Entire home/apt             4        1.0       1.0   1.0   $85.00
# 1  Entire home/apt             4        1.0       1.0   1.0  $150.00
# 2  Entire home/apt            11        4.5       5.0   7.0  $975.00
# 3  Entire home/apt             3        1.0       0.0   2.0  $100.00
# 4  Entire home/apt             6        2.0       3.0   3.0  $450.00
#
#    review_scores_rating  review_scores_location cancellation_policy
# 0                  95.0                     9.0            moderate
# 1                  96.0                    10.0              strict
# 2                  97.0                    10.0              strict
# 3                   NaN                     NaN            flexible
# 4                  92.0                     9.0              strict

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
# id                        3818 non-null int64
# host_response_rate        3295 non-null object
# neighbourhood_cleansed    3818 non-null object
# property_type             3817 non-null object
# room_type                 3818 non-null object
# accommodates              3818 non-null int64
# bathrooms                 3802 non-null float64
# bedrooms                  3812 non-null float64
# beds                      3817 non-null float64
# price                     3818 non-null object
# review_scores_rating      3171 non-null float64
# review_scores_location    3163 non-null float64
# cancellation_policy       3818 non-null object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 387.8+ KB

# %%
# get numeric variables
num_vars = df.select_dtypes(include = ['float64', 'int64']).columns
num_vars
# Out:
# Index(['id', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'review_scores_rating', 'review_scores_location'],
#       dtype='object')

# %%
# get numeric variables
num_vars = df.select_dtypes(include = ['float64', 'int64']).columns
num_vars
# Out:
# Index(['id', 'accommodates', 'bathrooms', 'bedrooms', 'beds',
#        'review_scores_rating', 'review_scores_location'],
#       dtype='object')

# %%
df[num_vars].describe()
# Out:
#                  id  accommodates    bathrooms     bedrooms         beds  \
# count  3.818000e+03   3818.000000  3802.000000  3812.000000  3817.000000
# mean   5.550111e+06      3.349398     1.259469     1.307712     1.735394
# std    2.962660e+06      1.977599     0.590369     0.883395     1.139480
# min    3.335000e+03      1.000000     0.000000     0.000000     1.000000
# 25%    3.258256e+06      2.000000     1.000000     1.000000     1.000000
# 50%    6.118244e+06      3.000000     1.000000     1.000000     1.000000
# 75%    8.035127e+06      4.000000     1.000000     2.000000     2.000000
# max    1.034016e+07     16.000000     8.000000     7.000000    15.000000
#
#        review_scores_rating  review_scores_location
# count           3171.000000             3163.000000
# mean              94.539262                9.608916
# std                6.606083                0.629053
# min               20.000000                4.000000
# 25%               93.000000                9.000000
# 50%               96.000000               10.000000
# 75%               99.000000               10.000000
# max              100.000000               10.000000

# %%
# get categorical variables
obj_vars = df.select_dtypes(include = ['object']).columns
obj_vars
# Out:
# Index(['host_response_rate', 'neighbourhood_cleansed', 'property_type',
#        'room_type', 'price', 'cancellation_policy'],
#       dtype='object')

# %%
obj_var_list = ['neighbourhood_cleansed','property_type', 'room_type', 'cancellation_policy']

df_obj = df[obj_var_list]
def bar_group (df, list_variable):
    j = 1
    for i in list_variable:
        plt.subplot(2,2,j)
        graph = df[i].value_counts().plot(kind = 'bar', subplots = True)
        j+=1
        # return graph

#df_obj['property_type'].value_counts().plot(kind = 'bar')
bar_group(df_obj,['neighbourhood_cleansed','property_type', 'room_type', 'cancellation_policy'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1393570 entries, 0 to 1393569
# Data columns (total 4 columns):
# listing_id    1393570 non-null int64
# date          1393570 non-null object
# available     1393570 non-null object
# price         934542 non-null object
# dtypes: int64(1), object(3)
# memory usage: 42.5+ MB

# %%
df1.head()
# Out:
#    listing_id        date available   price
# 0      241032  2016-01-04         t  $85.00
# 1      241032  2016-01-05         t  $85.00
# 2      241032  2016-01-06         f     NaN
# 3      241032  2016-01-07         f     NaN
# 4      241032  2016-01-08         f     NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1393570 entries, 0 to 1393569
# Data columns (total 90 columns):
# id                                  1393570 non-null int64
# listing_url                         1393570 non-null object
# scrape_id                           1393570 non-null int64
# last_scraped                        1393570 non-null object
# name                                1393570 non-null object
# summary                             1328965 non-null object
# space                               1185885 non-null object
# description                         1393570 non-null object
# experiences_offered                 1393570 non-null object
# neighborhood_overview               1016890 non-null object
# transit                             1052660 non-null object
# thumbnail_url                       1276770 non-null object
# medium_url                          1276770 non-null object
# picture_url                         1393570 non-null object
# xl_picture_url                      1276770 non-null object
# host_id                             1393570 non-null int64
# host_url                            1393570 non-null object
# host_name                           1392840 non-null object
# host_since                          1392840 non-null object
# host_location                       1390650 non-null object
# host_about                          1080035 non-null object
# host_response_time                  1202675 non-null object
# host_response_rate                  1202675 non-null object
# host_acceptance_rate                1111425 non-null object
# host_is_superhost                   1392840 non-null object
# host_thumbnail_url                  1392840 non-null object
# host_picture_url                    1392840 non-null object
# host_neighbourhood                  1284070 non-null object
# host_listings_count                 1392840 non-null float64
# host_total_listings_count           1392840 non-null float64
# host_verifications                  1393570 non-null object
# host_has_profile_pic                1392840 non-null object
# host_identity_verified              1392840 non-null object
# street                              1393570 non-null object
# neighbourhood                       1241730 non-null object
# neighbourhood_cleansed              1393570 non-null object
# neighbourhood_group_cleansed        1393570 non-null object
# city                                1393570 non-null object
# state                               1393570 non-null object
# zipcode                             1391015 non-null object
# market                              1393570 non-null object
# smart_location                      1393570 non-null object
# country_code                        1393570 non-null object
# country                             1393570 non-null object
# latitude                            1393570 non-null float64
# longitude                           1393570 non-null float64
# is_location_exact                   1393570 non-null object
# property_type                       1393205 non-null object
# room_type                           1393570 non-null object
# accommodates                        1393570 non-null int64
# bathrooms                           1387730 non-null float64
# bedrooms                            1391380 non-null float64
# beds                                1393205 non-null float64
# bed_type                            1393570 non-null object
# amenities                           1393570 non-null object
# price_x                             1393570 non-null object
# cleaning_fee                        1017620 non-null object
# guests_included                     1393570 non-null int64
# extra_people                        1393570 non-null object
# minimum_nights                      1393570 non-null int64
# maximum_nights                      1393570 non-null int64
# calendar_updated                    1393570 non-null object
# has_availability                    1393570 non-null object
# availability_30                     1393570 non-null int64
# availability_60                     1393570 non-null int64
# availability_90                     1393570 non-null int64
# availability_365                    1393570 non-null int64
# calendar_last_scraped               1393570 non-null object
# number_of_reviews                   1393570 non-null int64
# first_review                        1164715 non-null object
# last_review                         1164715 non-null object
# review_scores_rating                1157415 non-null float64
# review_scores_accuracy              1153400 non-null float64
# review_scores_cleanliness           1155225 non-null float64
# review_scores_checkin               1153400 non-null float64
# review_scores_communication         1155955 non-null float64
# review_scores_location              1154495 non-null float64
# review_scores_value                 1154130 non-null float64
# requires_license                    1393570 non-null object
# jurisdiction_names                  1393570 non-null object
# instant_bookable                    1393570 non-null object
# cancellation_policy                 1393570 non-null object
# require_guest_profile_picture       1393570 non-null object
# require_guest_phone_verification    1393570 non-null object
# calculated_host_listings_count      1393570 non-null int64
# reviews_per_month                   1164715 non-null float64
# listing_id                          1393570 non-null int64
# date                                1393570 non-null object
# available                           1393570 non-null object
# price_y                             934542 non-null object
# dtypes: float64(15), int64(14), object(61)
# memory usage: 967.5+ MB

# %%
df2.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 1  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 2  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 3  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
# 4  241032  https://www.airbnb.com/rooms/241032  20160104002432   2016-01-04
#
#                            name summary  \
# 0  Stylish Queen Anne Apartment     NaN
# 1  Stylish Queen Anne Apartment     NaN
# 2  Stylish Queen Anne Apartment     NaN
# 3  Stylish Queen Anne Apartment     NaN
# 4  Stylish Queen Anne Apartment     NaN
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Make your self at home in this charming one-be...
# 2  Make your self at home in this charming one-be...
# 3  Make your self at home in this charming one-be...
# 4  Make your self at home in this charming one-be...
#
#                                          description experiences_offered  \
# 0  Make your self at home in this charming one-be...                none
# 1  Make your self at home in this charming one-be...                none
# 2  Make your self at home in this charming one-be...                none
# 3  Make your self at home in this charming one-be...                none
# 4  Make your self at home in this charming one-be...                none
#
#   neighborhood_overview  ... instant_bookable cancellation_policy  \
# 0                   NaN  ...                f            moderate
# 1                   NaN  ...                f            moderate
# 2                   NaN  ...                f            moderate
# 3                   NaN  ...                f            moderate
# 4                   NaN  ...                f            moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#   calculated_host_listings_count  reviews_per_month listing_id        date  \
# 0                              2               4.07     241032  2016-01-04
# 1                              2               4.07     241032  2016-01-05
# 2                              2               4.07     241032  2016-01-06
# 3                              2               4.07     241032  2016-01-07
# 4                              2               4.07     241032  2016-01-08
#
#   available price_y
# 0         t  $85.00
# 1         t  $85.00
# 2         f     NaN
# 3         f     NaN
# 4         f     NaN
#
# [5 rows x 90 columns]

# %%
# check dtypes for the variables and see whether a conversion is needed.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
# id                        3818 non-null int64
# host_response_rate        3295 non-null object
# neighbourhood_cleansed    3818 non-null object
# property_type             3817 non-null object
# room_type                 3818 non-null object
# accommodates              3818 non-null int64
# bathrooms                 3802 non-null float64
# bedrooms                  3812 non-null float64
# beds                      3817 non-null float64
# price                     3818 non-null object
# review_scores_rating      3171 non-null float64
# review_scores_location    3163 non-null float64
# cancellation_policy       3818 non-null object
# dtypes: float64(5), int64(2), object(6)
# memory usage: 387.8+ KB

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Data prepration for the listing table

# %%
# Convert dtypes
df['host_response_rate_val'] = df['host_response_rate'].str.rstrip('%').astype(float)/100
df['price_val'] = df['price'].str.lstrip('$').str.replace(',', '').astype(float)

# %%
#how many missing values each variable has?
for num_var in num_vars:
    print(str(num_var) + ' ' + str(df[num_var].isnull().sum()))
# Out:
# id 0
# accommodates 0
# bathrooms 16
# bedrooms 6
# beds 1
# review_scores_rating 647
# review_scores_location 655

# %%
#replace NAs using means for numeric variable
for num_var in num_vars:
    df[num_var].fillna(df[num_var].mean(), inplace = True)

# %%
#check whether they are replaced
for num_var in num_vars:
    print(str(num_var) + ' ' + str(df[num_var].isnull().sum()))
# Out:
# id 0
# accommodates 0
# bathrooms 0
# bedrooms 0
# beds 0
# review_scores_rating 0
# review_scores_location 0

# %%
df.head()
# Out:
#         id host_response_rate neighbourhood_cleansed property_type  \
# 0   241032                96%        West Queen Anne     Apartment
# 1   953595                98%        West Queen Anne     Apartment
# 2  3308979                67%        West Queen Anne         House
# 3  7421966                NaN        West Queen Anne     Apartment
# 4   278830               100%        West Queen Anne         House
#
#          room_type  accommodates  bathrooms  bedrooms  beds    price  \
# 0  Entire home/apt             4        1.0       1.0   1.0   $85.00
# 1  Entire home/apt             4        1.0       1.0   1.0  $150.00
# 2  Entire home/apt            11        4.5       5.0   7.0  $975.00
# 3  Entire home/apt             3        1.0       0.0   2.0  $100.00
# 4  Entire home/apt             6        2.0       3.0   3.0  $450.00
#
#    review_scores_rating  review_scores_location cancellation_policy  \
# 0             95.000000                9.000000            moderate
# 1             96.000000               10.000000              strict
# 2             97.000000               10.000000              strict
# 3             94.539262                9.608916            flexible
# 4             92.000000                9.000000              strict
#
#    host_response_rate_val  price_val
# 0                    0.96       85.0
# 1                    0.98      150.0
# 2                    0.67      975.0
# 3                     NaN      100.0
# 4                    1.00      450.0

# %% [markdown]
# ## Data preparation for the calendar table

# %%
#Convert date_trans to datetime type, slice the data of 2016, convert 'available' from "t and f" to "0 and 1"
df1['date_trans'] = pd.to_datetime(df1['date'])
df1['date_month'] = df1['date_trans'].apply(lambda x: x.strftime('%m'))

df1 = df1[(df1['date_trans'] >= pd.datetime(2016,1,1)) & (df1['date_trans'] <= pd.datetime(2016,12,31))]
df1['available_bool'] = np.where(df1['available'].str.contains('f'), 1,0)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Question 1: Number of Airbnb properties by neighborhood

# %%
#How many Airbnb properties in Seattle
total_properties = len(np.unique(df['id']))
total_properties
# Out:
# 3818

# %%
#Create groupby_stats() function:
def groupby_stats(df, method, stats_var, grouping_var):
    ''' Description: group var A by var B and conduct statistical analysis on A
        Arguments:
            df: dataset
            method: statistical method to use
            stats_var: the variable to be analyzed
            grouping_var: the variable used to do grouping
        Return:
            a dataframe where the index is the grouping_var, and the values are the statistical values of stats_var
    '''
    df_grouping1 = df.groupby(df[grouping_var])[stats_var]
    
    if method == 'sum':
        df_grouping2 = df_grouping1.sum()
    elif method == 'mean':
        df_grouping2 = df_grouping1.mean()
    elif method == 'count':
        df_grouping2 = df_grouping1.count()
    return pd.DataFrame(df_grouping2.sort_values(ascending = False))
  #  return df_grouping

# %%
#number of properties by neighborhood
number_properties = groupby_stats(df, 'count', 'id', 'neighbourhood_cleansed')
number_properties.head()
# Out:
#                          id
# neighbourhood_cleansed
# Broadway                397
# Belltown                234
# Wallingford             167
# Fremont                 158
# Minor                   135

# %%
# number of properties in a few communities
print(number_properties.loc[['Pike-Market', 'Alki', 'Fauntleroy', 'Highland Park', 'South Beacon Hill', 'South Park']])
# Out:
#                         id
# neighbourhood_cleansed
# Pike-Market             28
# Alki                    42
# Fauntleroy              10
# Highland Park           11
# South Beacon Hill        4
# South Park               3

# %%
# Market share by neighborhood
proportion_properties = number_properties/number_properties.sum()
proportion_properties = proportion_properties.rename(columns = {'id': 'proportion'})
proportion_properties.head()
# Out:
#                         proportion
# neighbourhood_cleansed
# Broadway                  0.103981
# Belltown                  0.061289
# Wallingford               0.043740
# Fremont                   0.041383
# Minor                     0.035359

# %%
# Market share for a few communities
proportion_properties.loc[['Montlake', 'Westlake', 'South Lake Union', 'Madrona', 'East Queen Anne', 'North Beach/Blue Ridge', 'Belltown', 'West Queen Anne']]
# Out:
#                         Number of properties
# neighbourhood_cleansed
# Montlake                            0.004976
# Westlake                            0.004453
# South Lake Union                    0.007072
# Madrona                             0.012310
# East Queen Anne                     0.021477
# North Beach/Blue Ridge              0.003667
# Belltown                            0.061289
# West Queen Anne                     0.017025

# %%
# Market share for the top three communities
proportion_properties.iloc[0:3].sum()
# Out:
# proportion    0.20901
# dtype: float64

# %% [markdown]
# ## Question 2: Ten top rated neighbourhood by location

# %%
rating_by_neighbor = pd.DataFrame(df.groupby(df['neighbourhood_cleansed'])['review_scores_location'].mean().sort_values(ascending = False))
rating_by_neighbor
# Out:
#                            review_scores_location
# neighbourhood_cleansed
# Pike-Market                              9.913043
# Alki                                     9.892857
# Fauntleroy                               9.888889
# Laurelhurst                              9.888889
# Adams                                    9.877193
# Lower Queen Anne                         9.876712
# Sunset Hill                              9.866667
# Genesee                                  9.866667
# Green Lake                               9.863636
# Fremont                                  9.858209
# Windermere                               9.857143
# Central Business District                9.853933
# Stevens                                  9.851064
# North Admiral                            9.846154
# Broadway                                 9.831776
# Belltown                                 9.817734
# First Hill                               9.800000
# Whittier Heights                         9.791667
# Southeast Magnolia                       9.785714
# Madison Park                             9.785714
# Madrona                                  9.775000
# Wallingford                              9.772414
# West Queen Anne                          9.763636
# Gatewood                                 9.750000
# Briarcliff                               9.750000
# Seaview                                  9.727273
# Phinney Ridge                            9.724138
# Loyal Heights                            9.720930
# North Queen Anne                         9.702128
# Montlake                                 9.687500
# ...                                           ...
# Mount Baker                              9.309524
# Mann                                     9.309091
# Wedgwood                                 9.307692
# Victory Heights                          9.285714
# Seward Park                              9.282051
# University District                      9.252632
# North Beacon Hill                        9.188406
# High Point                               9.181818
# Georgetown                               9.125000
# Riverview                                9.125000
# Crown Hill                               9.117647
# Interbay                                 9.111111
# South Delridge                           9.100000
# Atlantic                                 9.095238
# Haller Lake                              9.090909
# Brighton                                 9.090909
# International District                   9.076923
# Mid-Beacon Hill                          9.035714
# Columbia City                            8.980392
# Rainier Beach                            8.933333
# Olympic Hills                            8.928571
# Cedar Park                               8.833333
# Industrial District                      8.750000
# Dunlap                                   8.666667
# Arbor Heights                            8.666667
# Holly Park                               8.500000
# Pinehurst                                8.500000
# Highland Park                            8.444444
# South Beacon Hill                        8.000000
# South Park                               8.000000
#
# [87 rows x 1 columns]

# %%
rating_by_neighbor = groupby_stats(df, 'mean', 'review_scores_location', 'neighbourhood_cleansed')
rating_by_neighbor
# Out:
#                            review_scores_location
# neighbourhood_cleansed
# Fauntleroy                               9.860892
# Laurelhurst                              9.860892
# Pike-Market                              9.858735
# Genesee                                  9.836343
# Adams                                    9.827370
# Sunset Hill                              9.823708
# Central Business District                9.820629
# Fremont                                  9.820342
# Lower Queen Anne                         9.816885
# Green Lake                               9.816466
# Stevens                                  9.800192
# Alki                                     9.798210
# North Admiral                            9.797738
# Belltown                                 9.790070
# Broadway                                 9.789112
# Windermere                               9.782675
# Whittier Heights                         9.777609
# First Hill                               9.768153
# Southeast Magnolia                       9.754515
# Wallingford                              9.750875
# Madrona                                  9.750264
# Madison Park                             9.746426
# West Queen Anne                          9.739833
# Briarcliff                               9.729845
# Seaview                                  9.717410
# Gatewood                                 9.711522
# Loyal Heights                            9.701543
# Phinney Ridge                            9.700462
# North Queen Anne                         9.690045
# Montlake                                 9.675092
# ...                                           ...
# Mount Baker                              9.357426
# University District                      9.331481
# Pioneer Square                           9.330822
# Broadview                                9.329936
# Seward Park                              9.319195
# Victory Heights                          9.307261
# High Point                               9.273339
# North Beacon Hill                        9.236926
# Haller Lake                              9.229044
# Crown Hill                               9.211222
# International District                   9.202098
# Atlantic                                 9.201850
# Interbay                                 9.201621
# South Delridge                           9.184819
# Brighton                                 9.170602
# Riverview                                9.125000
# Georgetown                               9.125000
# Mid-Beacon Hill                          9.073928
# South Park                               9.072610
# Columbia City                            9.056248
# Rainier Beach                            9.045930
# Arbor Heights                            9.043566
# Industrial District                      9.036305
# Cedar Park                               9.027229
# Olympic Hills                            9.013614
# Dunlap                                   8.902229
# Holly Park                               8.869639
# South Beacon Hill                        8.804458
# Highland Park                            8.656166
# Pinehurst                                8.500000
#
# [87 rows x 1 columns]

# %%
#Concat rating and number of properties: how saturated the market is in the communities of 'good location'
rating_properties = pd.merge(rating_by_neighbor, number_properties, on = 'neighbourhood_cleansed')
rating_properties.iloc[0:11]
# Out:
#                            review_scores_location   id
# neighbourhood_cleansed
# Fauntleroy                               9.860892   10
# Laurelhurst                              9.860892   10
# Pike-Market                              9.858735   28
# Genesee                                  9.836343   34
# Adams                                    9.827370   70
# Sunset Hill                              9.823708   18
# Central Business District                9.820629  103
# Fremont                                  9.820342  158
# Lower Queen Anne                         9.816885   94
# Green Lake                               9.816466   54
# Stevens                                  9.800192  119

# %% [markdown]
# ## Question 3  Occupancy rate and monthly revenue by neighbourhood in 2016

# %% [markdown]
# ### Calculate the occupancy rate by neighbourhood

# %%
occupancy_neighbour = groupby_stats(df2, 'sum', 'available_bool', 'neighbourhood_cleansed')
total_neighbour = groupby_stats(df2, 'count', 'available_bool', 'neighbourhood_cleansed')
occupancy_rate_neighbour = occupancy_neighbour / total_neighbour
occupancy_rate_neighbour.sort_values(ascending = False, by = ['available_bool'])
# Out:
#                            available_bool
# neighbourhood_cleansed
# South Lake Union                 0.547903
# South Beacon Hill                0.497934
# North Beach/Blue Ridge           0.485636
# Seaview                          0.477961
# Riverview                        0.456267
# Montlake                         0.437292
# Madrona                          0.435496
# Lower Queen Anne                 0.433533
# Genesee                          0.424567
# First Hill                       0.409627
# Haller Lake                      0.403857
# Wedgwood                         0.401286
# East Queen Anne                  0.401062
# International District           0.400097
# Atlantic                         0.391392
# Westlake                         0.389726
# Adams                            0.384455
# Mount Baker                      0.383691
# Broadway                         0.376418
# Belltown                         0.375597
# Ravenna                          0.374244
# Dunlap                           0.366667
# Eastlake                         0.363942
# Fauntleroy                       0.361708
# Bitter Lake                      0.358974
# Greenwood                        0.355558
# Phinney Ridge                    0.353862
# Roosevelt                        0.352342
# Madison Park                     0.348485
# View Ridge                       0.332940
# ...                                   ...
# Windermere                       0.274931
# Cedar Park                       0.273072
# Central Business District        0.271336
# North Admiral                    0.271097
# Rainier Beach                    0.270738
# Yesler Terrace                   0.269648
# Alki                             0.265775
# Harrison/Denny-Blaine            0.265250
# Portage Bay                      0.256592
# University District              0.255747
# Fairmount Park                   0.253824
# Loyal Heights                    0.247457
# Arbor Heights                    0.238567
# Olympic Hills                    0.234848
# Georgetown                       0.234848
# Broadview                        0.232539
# Maple Leaf                       0.214220
# Pioneer Square                   0.212840
# Matthews Beach                   0.202987
# Victory Heights                  0.197245
# Southeast Magnolia               0.183439
# Gatewood                         0.178187
# Sunset Hill                      0.161922
# Interbay                         0.155021
# Industrial District              0.143710
# Briarcliff                       0.134986
# Highland Park                    0.126471
# High Point                       0.056277
# Roxhill                          0.046832
# Holly Park                       0.028007
#
# [87 rows x 1 columns]

# %% [markdown]
# ### Calculate the average price by neighbourhood

# %%
price_by_neighbor = groupby_stats(df2, 'mean', 'price_val', 'neighbourhood_cleansed')
price_by_neighbor.sort_values(ascending = False, by = ['price_val'])
# Out:
#                             price_val
# neighbourhood_cleansed
# Southeast Magnolia         231.705882
# Portage Bay                227.857143
# Westlake                   194.470588
# West Queen Anne            187.769231
# Montlake                   182.789474
# Briarcliff                 176.571429
# Sunset Hill                176.055556
# Industrial District        173.333333
# Alki                       171.619048
# Windermere                 169.900000
# Pioneer Square             169.260870
# Central Business District  164.213592
# Fauntleroy                 164.100000
# Belltown                   162.893162
# East Queen Anne            159.414634
# Madrona                    158.234043
# Pike-Market                157.785714
# North Queen Anne           150.240741
# Green Lake                 149.018519
# Lawton Park                147.566667
# Holly Park                 147.166667
# North Admiral              146.408163
# View Ridge                 139.000000
# Lower Queen Anne           138.202128
# First Hill                 136.425926
# South Lake Union           135.481481
# Leschi                     134.358491
# Stevens                    133.210084
# Mann                       131.985075
# Madison Park               130.388889
# ...                               ...
# Matthews Beach             107.105263
# International District     104.882353
# High Point                 104.357143
# Haller Lake                103.400000
# Greenwood                   98.820225
# Meadowbrook                 98.666667
# Mount Baker                 98.300000
# North Beacon Hill           96.884615
# Columbia City               95.017241
# Broadview                   94.705882
# University District         93.639344
# Roxhill                     92.500000
# Brighton                    91.230769
# South Park                  90.000000
# North College Park          89.105263
# Ravenna                     88.686567
# Dunlap                      88.300000
# Crown Hill                  87.666667
# Highland Park               86.272727
# South Beacon Hill           83.250000
# Bitter Lake                 83.000000
# Victory Heights             81.466667
# Riverview                   80.500000
# Maple Leaf                  80.261905
# Mid-Beacon Hill             79.933333
# North Delridge              76.375000
# Georgetown                  76.125000
# South Delridge              74.666667
# Olympic Hills               71.687500
# Rainier Beach               68.555556
#
# [87 rows x 1 columns]

# %%
#Get prices for a few communities
price_by_neighbor.loc[['Pike-Market', 'Alki', 'Fauntleroy']]
# Out:
#                          price_val
# neighbourhood_cleansed
# Pike-Market             157.785714
# Alki                    171.619048
# Fauntleroy              164.100000

# %% [markdown]
# ### Calculate monthly reveunue by neighbourhood

# %%
monthly_income_neighbour = pd.DataFrame(30*occupancy_rate_neighbour['available_bool'].multiply(price_by_neighbor['price_val'], axis = "index"))
monthly_income_neighbour = monthly_income_neighbour.rename(columns = {0:'monthly revenue'}).sort_values(ascending = False, by = ['monthly revenue'])
monthly_income_neighbour
# Out:
#                            monthly revenue
# neighbourhood_cleansed
# Montlake                       2397.968911
# Westlake                       2273.708141
# South Lake Union               2226.922423
# Madrona                        2067.309541
# East Queen Anne                1918.052714
# North Beach/Blue Ridge         1869.003205
# Belltown                       1835.467773
# West Queen Anne                1829.466771
# Lower Queen Anne               1797.453908
# Fauntleroy                     1780.688430
# Portage Bay                    1753.988868
# Seaview                        1694.373278
# First Hill                     1676.510518
# Pike-Market                    1568.542756
# Genesee                        1553.538849
# North Queen Anne               1456.190100
# Adams                          1403.315449
# Windermere                     1401.323967
# Broadway                       1399.024054
# Green Lake                     1396.449937
# View Ridge                     1388.358914
# Phinney Ridge                  1374.973597
# Alki                           1368.359663
# Madison Park                   1363.156566
# Roosevelt                      1358.629201
# Central Business District      1336.714189
# Eastlake                       1335.668809
# Wedgwood                       1329.592899
# Atlantic                       1307.989373
# Lawton Park                    1290.293664
# ...                                    ...
# North Beacon Hill               908.691053
# Arbor Heights                   907.510744
# Meadowbrook                     906.029997
# Bitter Lake                     893.846154
# Crown Hill                      873.561590
# Brighton                        860.689520
# Sunset Hill                     855.219365
# North College Park              844.155125
# Columbia City                   834.413307
# Loyal Heights                   812.039953
# South Park                      788.429752
# North Delridge                  762.566503
# Industrial District             747.291093
# University District             718.438703
# Briarcliff                      715.041322
# Mid-Beacon Hill                 682.626263
# Gatewood                        664.555871
# Broadview                       660.685178
# Matthews Beach                  652.228658
# South Delridge                  637.649219
# Rainier Beach                   556.817162
# Georgetown                      536.335227
# Maple Leaf                      515.811454
# Interbay                        510.301892
# Olympic Hills                   505.071023
# Victory Heights                 482.067218
# Highland Park                   327.330783
# High Point                      176.187384
# Roxhill                         129.958678
# Holly Park                      123.652433
#
# [87 rows x 1 columns]

# %% [markdown]
# ### Bar plot the five most profitable Airbnb properties by neighborhood

# %%
g_income = monthly_income_neighbour.head(n=5)
g_income.info()
g_income.plot.bar()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Montlake to East Queen Anne
# Data columns (total 1 columns):
# monthly revenue    5 non-null float64
# dtypes: float64(1)
# memory usage: 80.0+ bytes

# %%
#Get monthly revenue for a few communities
monthly_income_neighbour.loc[['Broadway', 'Belltown', 'Wallingford', 'Pike-Market', 'Alki', 'Fauntleroy']]
# Out:
#                         monthly revenue
# neighbourhood_cleansed
# Broadway                    1399.024054
# Belltown                    1835.467773
# Wallingford                 1150.013860
# Pike-Market                 1568.542756
# Alki                        1368.359663
# Fauntleroy                  1780.688430

# %%
#Merge revenue and proportion to see: how profitable the properties are by neighbourhood? How saturated the market is? (Any potential for market entry)
revenue_proportion = pd.merge(monthly_income_neighbour, proportion_properties, on = 'neighbourhood_cleansed')
revenue_proportion
# Out:
#                            monthly revenue  proportion
# neighbourhood_cleansed
# Montlake                       2397.968911    0.004976
# Westlake                       2273.708141    0.004453
# South Lake Union               2226.922423    0.007072
# Madrona                        2067.309541    0.012310
# East Queen Anne                1918.052714    0.021477
# North Beach/Blue Ridge         1869.003205    0.003667
# Belltown                       1835.467773    0.061289
# West Queen Anne                1829.466771    0.017025
# Lower Queen Anne               1797.453908    0.024620
# Fauntleroy                     1780.688430    0.002619
# Portage Bay                    1753.988868    0.003667
# Seaview                        1694.373278    0.003143
# First Hill                     1676.510518    0.028287
# Pike-Market                    1568.542756    0.007334
# Genesee                        1553.538849    0.008905
# North Queen Anne               1456.190100    0.014144
# Adams                          1403.315449    0.018334
# Windermere                     1401.323967    0.002619
# Broadway                       1399.024054    0.103981
# Green Lake                     1396.449937    0.014144
# View Ridge                     1388.358914    0.001833
# Phinney Ridge                  1374.973597    0.019120
# Alki                           1368.359663    0.011001
# Madison Park                   1363.156566    0.004715
# Roosevelt                      1358.629201    0.007858
# Central Business District      1336.714189    0.026977
# Eastlake                       1335.668809    0.011786
# Wedgwood                       1329.592899    0.004715
# Atlantic                       1307.989373    0.013882
# Lawton Park                    1290.293664    0.007858
# ...                                    ...         ...
# North Beacon Hill               908.691053    0.020430
# Arbor Heights                   907.510744    0.001310
# Meadowbrook                     906.029997    0.002357
# Bitter Lake                     893.846154    0.003405
# Crown Hill                      873.561590    0.005500
# Brighton                        860.689520    0.003405
# Sunset Hill                     855.219365    0.004715
# North College Park              844.155125    0.004976
# Columbia City                   834.413307    0.015191
# Loyal Heights                   812.039953    0.013620
# South Park                      788.429752    0.000786
# North Delridge                  762.566503    0.008381
# Industrial District             747.291093    0.001572
# University District             718.438703    0.031954
# Briarcliff                      715.041322    0.003667
# Mid-Beacon Hill                 682.626263    0.007858
# Gatewood                        664.555871    0.005762
# Broadview                       660.685178    0.004453
# Matthews Beach                  652.228658    0.004976
# South Delridge                  637.649219    0.003143
# Rainier Beach                   556.817162    0.004715
# Georgetown                      536.335227    0.002095
# Maple Leaf                      515.811454    0.011001
# Interbay                        510.301892    0.002881
# Olympic Hills                   505.071023    0.004191
# Victory Heights                 482.067218    0.003929
# Highland Park                   327.330783    0.002881
# High Point                      176.187384    0.003667
# Roxhill                         129.958678    0.000524
# Holly Park                      123.652433    0.001572
#
# [87 rows x 2 columns]

# %% [markdown]
# ## Question 4:  Monthly revenue by property type

# %% [markdown]
# ### Occupancy rate by property

# %%
occupancy_property = groupby_stats(df2, 'sum', 'available_bool', 'property_type')

#df2.groupby(df2['property_type'])['available_bool'].sum()
total_property = groupby_stats(df2, 'count', 'available_bool', 'property_type')
occupancy_rate_property = occupancy_property / total_property
occupancy_rate_property = pd.DataFrame(occupancy_rate_property.sort_values(ascending = False, by = ['available_bool']))
occupancy_rate_property = occupancy_rate_property.rename(columns = {'available_bool' : 'occupancy rate'})
occupancy_rate_property
# Out:
#                  occupancy rate
# property_type
# Tent                   0.522865
# Yurt                   0.512397
# Condominium            0.421790
# Dorm                   0.418733
# Treehouse              0.385675
# Townhouse              0.370220
# Apartment              0.346604
# Cabin                  0.337400
# Loft                   0.322796
# House                  0.310103
# Bungalow               0.302183
# Camper/RV              0.279085
# Bed & Breakfast        0.269972
# Boat                   0.221419
# Other                  0.134485
# Chalet                 0.088154

# %% [markdown]
# ### Average price by property

# %%
avg_price_property = groupby_stats(df2, 'mean', 'price_val', 'property_type')
avg_price_property = pd.DataFrame(avg_price_property )
avg_price_property = avg_price_property.rename(columns = {'price_val' : 'price per night'})
avg_price_property
# Out:
#                  price per night
# property_type
# Boat                  282.375000
# Condominium           151.109890
# Loft                  135.700000
# House                 132.351414
# Townhouse             129.457627
# Apartment             122.932670
# Camper/RV             120.461538
# Bungalow              115.615385
# Bed & Breakfast       112.054054
# Cabin                 104.666667
# Treehouse             101.000000
# Yurt                  100.000000
# Chalet                 98.500000
# Other                  94.681818
# Tent                   54.000000
# Dorm                   39.500000

# %% [markdown]
# ### Monthly revenue by property

# %%
monthly_income_property = pd.DataFrame(30*occupancy_rate_property['occupancy rate'].multiply(avg_price_property['price per night'], axis = "index"))
monthly_income_property = monthly_income_property.rename(columns = {0 : 'monthly revenue'}).sort_values(ascending = False, by = ['monthly revenue'])
monthly_income_property
# Out:
#                  monthly revenue
# property_type
# Condominium          1912.100716
# Boat                 1875.693440
# Yurt                 1537.190083
# Townhouse            1437.833766
# Loft                 1314.103099
# Apartment            1278.269447
# House                1231.275314
# Treehouse            1168.595041
# Cabin                1059.435918
# Bungalow             1048.108954
# Camper/RV            1008.568634
# Bed & Breakfast       907.545231
# Tent                  847.041322
# Dorm                  496.198347
# Other                 381.999522
# Chalet                260.495868

# %%
#merge monthly revenue, price, occupancy rate by property for better presentation
revenue_property = pd.merge(pd.merge(monthly_income_property,avg_price_property,on = 'property_type'), occupancy_rate_property, on = 'property_type')
revenue_property
# Out:
#                  monthly revenue  price per night  occupancy rate
# property_type
# Condominium          1912.100716       151.109890        0.421790
# Boat                 1875.693440       282.375000        0.221419
# Yurt                 1537.190083       100.000000        0.512397
# Townhouse            1437.833766       129.457627        0.370220
# Loft                 1314.103099       135.700000        0.322796
# Apartment            1278.269447       122.932670        0.346604
# House                1231.275314       132.351414        0.310103
# Treehouse            1168.595041       101.000000        0.385675
# Cabin                1059.435918       104.666667        0.337400
# Bungalow             1048.108954       115.615385        0.302183
# Camper/RV            1008.568634       120.461538        0.279085
# Bed & Breakfast       907.545231       112.054054        0.269972
# Tent                  847.041322        54.000000        0.522865
# Dorm                  496.198347        39.500000        0.418733
# Other                 381.999522        94.681818        0.134485
# Chalet                260.495868        98.500000        0.088154

# %% [markdown]
# ### Bar plot monthly revenue by property type

# %%
monthly_income_property.plot.bar()

# %% [markdown]
# #
